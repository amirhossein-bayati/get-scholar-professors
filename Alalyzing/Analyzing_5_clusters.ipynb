# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# # Import dataset

# %%
df = pd.read_excel('../Data-gathering/Json/Final_Dataset.xlsx')
df = df.drop(['Index',
           'Date',
           'index',
           'Author name',
           'University',
           'country',
           'Google Scholar link of the university',
           'Google Scholar link of the author',
           'Qs uni world ranking',
           'Qs uni country ranking',
           'Date of the first publication (year)',
           'Date of the last publication (year)',
           "Author's positin in top 100 pages",
            ], axis=1)
cols = df.columns
main_df = df

# %% [markdown]
# # Minmax scaler

# %%
scaler = preprocessing.MinMaxScaler()
scaled = scaler.fit_transform(main_df)
min_maxed_df = pd.DataFrame(scaled, columns=[cols])

# %% [markdown]
# # Normalization

# %%
df_normalized = preprocessing.normalize(min_maxed_df)
dfcopy = df_normalized
df = pd.DataFrame(df_normalized, columns=[cols])

# %% [markdown]
# # PCA

# %%
Newdf = pd.DataFrame(df, columns=[cols])
pca = PCA(2)
Newdf = pca.fit_transform(df)
data = Newdf.copy()
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(data)

label = kmeans.fit_predict(data)
fig, ax = plt.subplots(figsize=(10, 10))

u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(data[label == i , 0] , data[label == i , 1] )
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# No handles with labels found to put in legend.

# %% [markdown]
# # Trian model with 5 clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df)

label = kmeans.fit_predict(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %% [markdown]
# # Assign clusters to dataframe

# %%
main_df['Cluster'] = label
main_df = main_df.astype({"Cluster": int})

# %% [markdown]
# # Clusters histogram

# %%
main_df['Cluster'].hist()

# %%
cluster_groups = main_df.groupby('Cluster')

# %% [markdown]
# # Histogram of each cluster

# %%
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
  fig.suptitle(f'Cluster {cluster + 1}', fontsize=16)
  i = 0
  j = 0
  for col in group.columns:
      if j == 4:
          i += 1
          j = 0
      if col == 'Cluster':
        pass
      else:
        ax[i, j].set(title = col)
        ax[i, j].hist(group[col])
      j += 1

# %% [markdown]
# # Data summary of each cluster

# %%
min_max_clusters = []
from sklearn.utils.fixes import threadpool_limits
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  statistical = []
  temp_min_max = {
      'cluster': cluster,
      'min': [],
      'max': [],
  }
  for col in group.columns:
      statistical_par = {
              'Minimum': round(group[col].min(),2),
              'Maximum': round(group[col].max(),2),
              'Median':  round(group[col].median(),2),
              'Mean':    round(group[col].mean(),2),
              'STD':     round(group[col].std(),2),
              'Variance':round(group[col].var(),2)
          }
      
      temp_min_max['max'].append({col:statistical_par['Maximum']})
      temp_min_max['min'].append({col:statistical_par['Minimum']})
      statistical.append(statistical_par)
  min_max_clusters.append(temp_min_max)
  temp = pd.DataFrame(
      statistical, 
      index = group.columns
  )
  print(f"\n\nCluster {cluster + 1}", end="\n")
  display(temp)
# Out:
# Cluster 1
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                14.00  34824.00  1635.00  2441.53
# h-index                                  2.00     56.00    21.00    21.83
# i10-index                                0.00    131.00    36.00    39.53
# No. Of Publications                     10.00   1443.00   117.00   141.25
# No. Of publications without citation     5.00   1358.00    41.00    58.95
# Uncited rate                             0.13      0.94     0.38     0.39
# No.Of US pattent                         0.00     28.00     0.00     0.31
# Patents and Publications balance         0.00      0.31     0.00     0.00
# The most citation                        3.00   8484.00   181.00   323.84
# The most citation density                0.03      0.44     0.12     0.13
# Sum of top 10 citations                 14.00  27946.00   864.00  1353.40
# Sum of top 10 citations density          1.17   2328.83    72.00   112.78
# Observation time window (years)          3.00    294.00    26.00    31.72
# average citation per publication         0.19    274.96    13.38    17.53
# average citation per year                0.47   3746.38    60.29    90.81
# average publication per year             0.33     34.36     4.38     5.06
# Cluster                                  0.00      0.00     0.00     0.00
#
#                                           STD    Variance
# Citation                              2819.43  7949208.91
# h-index                                  9.50       90.34
# i10-index                               24.42      596.54
# No. Of Publications                    103.57    10727.58
# No. Of publications without citation    64.58     4171.00
# Uncited rate                             0.12        0.01
# No.Of US pattent                         1.50        2.24
# Patents and Publications balance         0.01        0.00
# The most citation                      507.57   257623.44
# The most citation density                0.05        0.00
# Sum of top 10 citations               1859.68  3458396.49
# Sum of top 10 citations density        154.97    24016.64
# Observation time window (years)         22.41      502.02
# average citation per publication        17.38      302.03
# average citation per year              141.02    19887.51
# average publication per year             3.11        9.65
# Cluster                                  0.00        0.00
# Cluster 2
#                                       Minimum    Maximum    Median      Mean  \
# Citation                               900.00  744199.00  28436.00  42851.72
# h-index                                 19.00     299.00     80.00     86.14
# i10-index                               33.00    1904.00    257.00    305.17
# No. Of Publications                     38.00    3000.00    470.00    605.01
# No. Of publications without citation     0.00    1807.00    104.00    164.42
# Uncited rate                             0.00       0.72      0.22      0.22
# No.Of US pattent                         0.00     716.00      0.00      6.63
# Patents and Publications balance         0.00       0.52      0.00      0.01
# The most citation                       50.00  126878.00   1938.00   4544.73
# The most citation density                0.01       0.40      0.07      0.09
# Sum of top 10 citations                343.00  632866.00   8242.00  15527.83
# Sum of top 10 citations density         28.58   52738.83    686.83   1293.99
# Observation time window (years)          3.00    2021.00     36.00     66.11
# average citation per publication         9.16     919.08     59.74     81.37
# average citation per year               12.78   13599.33    746.98   1166.68
# average publication per year             0.15     175.00     12.59     15.83
# Cluster                                  1.00       1.00      1.00      1.00
#
#                                            STD      Variance
# Citation                              45695.40  2.088070e+09
# h-index                                  34.79  1.210510e+03
# i10-index                               213.63  4.563923e+04
# No. Of Publications                     494.19  2.442253e+05
# No. Of publications without citation    198.01  3.920934e+04
# Uncited rate                              0.11  1.000000e-02
# No.Of US pattent                         25.65  6.578500e+02
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      7983.43  6.373516e+07
# The most citation density                 0.06  0.000000e+00
# Sum of top 10 citations               23961.24  5.741409e+08
# Sum of top 10 citations density        1996.77  3.987090e+06
# Observation time window (years)         211.91  4.490795e+04
# average citation per publication         72.76  5.294160e+03
# average citation per year              1325.51  1.756975e+06
# average publication per year             12.82  1.643500e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 3
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  176539.00  2346.00  7928.52
# h-index                                  1.00      87.00    17.00    21.46
# i10-index                                0.00     263.00    21.00    36.87
# No. Of Publications                      1.00     511.00    45.00    73.78
# No. Of publications without citation     0.00     218.00     7.00    16.23
# Uncited rate                             0.00       0.67     0.17     0.20
# No.Of US pattent                         0.00      47.00     0.00     0.45
# Patents and Publications balance         0.00       0.83     0.00     0.00
# The most citation                        1.00  126317.00   825.50  3801.04
# The most citation density                0.08       1.00     0.39     0.44
# Sum of top 10 citations                  1.00  188615.00  1919.50  6643.16
# Sum of top 10 citations density          0.08   15717.92   159.96   553.60
# Observation time window (years)          1.00    2013.00    18.00    26.51
# average citation per publication         0.50    4864.50    50.29   105.70
# average citation per year                0.42   16344.62   137.53   370.98
# average publication per year             0.01      27.55     2.54     3.41
# Cluster                                  2.00       2.00     2.00     2.00
#
#                                            STD      Variance
# Citation                              14456.00  2.089760e+08
# h-index                                  16.14  2.605400e+02
# i10-index                                40.35  1.628290e+03
# No. Of Publications                      80.81  6.530170e+03
# No. Of publications without citation     25.18  6.341200e+02
# Uncited rate                              0.13  2.000000e-02
# No.Of US pattent                          2.35  5.530000e+00
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      8584.38  7.369162e+07
# The most citation density                 0.22  5.000000e-02
# Sum of top 10 citations               14217.90  2.021486e+08
# Sum of top 10 citations density        1184.82  1.403810e+06
# Observation time window (years)         103.73  1.075933e+04
# average citation per publication        241.20  5.817532e+04
# average citation per year               816.65  6.669141e+05
# average publication per year              2.81  7.890000e+00
# Cluster                                   0.00  0.000000e+00
# Cluster 4
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  104130.00  1237.50  3718.94
# h-index                                  1.00      87.00    16.00    18.61
# i10-index                                0.00     247.00    21.00    30.74
# No. Of Publications                      4.00     903.00    58.00    84.95
# No. Of publications without citation     2.00     506.00    17.00    28.34
# Uncited rate                             0.08       0.96     0.31     0.33
# No.Of US pattent                         0.00      45.00     0.00     0.38
# Patents and Publications balance         0.00       0.53     0.00     0.00
# The most citation                        1.00   42314.00   286.00  1087.16
# The most citation density                0.08       1.00     0.25     0.28
# Sum of top 10 citations                  1.00   91469.00   920.50  2774.76
# Sum of top 10 citations density          0.08    7622.42    76.71   231.23
# Observation time window (years)          2.00    2021.00    21.00    29.84
# average citation per publication         0.10     732.71    20.65    34.43
# average citation per year                0.10    4120.17    57.48   141.86
# average publication per year             0.03      26.15     2.85     3.51
# Cluster                                  3.00       3.00     3.00     3.00
#
#                                           STD     Variance
# Citation                              7719.70  59593828.11
# h-index                                 12.23       149.50
# i10-index                               30.98       959.81
# No. Of Publications                     85.00      7225.38
# No. Of publications without citation    36.86      1358.36
# Uncited rate                             0.13         0.02
# No.Of US pattent                         2.08         4.32
# Patents and Publications balance         0.02         0.00
# The most citation                     2644.09   6991212.22
# The most citation density                0.13         0.02
# Sum of top 10 citations               6427.75  41315912.86
# Sum of top 10 citations density        535.65    286916.06
# Observation time window (years)         93.95      8825.97
# average citation per publication        49.96      2496.04
# average citation per year              276.25     76316.21
# average publication per year             2.57         6.61
# Cluster                                  0.00         0.00
# Cluster 5
#                                       Minimum    Maximum   Median      Mean  \
# Citation                               568.00  225629.00  9175.00  12300.72
# h-index                                 10.00     150.00    48.00     50.33
# i10-index                               12.00     421.00   127.00    138.78
# No. Of Publications                     43.00    2236.00   307.00    366.43
# No. Of publications without citation     5.00    1424.00    92.00    132.41
# Uncited rate                             0.07       0.82     0.30      0.31
# No.Of US pattent                         0.00     344.00     0.00      2.10
# Patents and Publications balance         0.00       0.95     0.00      0.01
# The most citation                       22.00   44738.00   646.00   1293.76
# The most citation density                0.01       0.43     0.07      0.09
# Sum of top 10 citations                186.00  214306.00  3105.00   5004.95
# Sum of top 10 citations density         15.50   17858.83   258.75    417.08
# Observation time window (years)          1.00    2021.00    34.00     53.26
# average citation per publication         1.28    1683.80    29.71     38.49
# average citation per year                1.06    6267.47   264.69    355.25
# average publication per year             0.07     101.00     8.88     10.40
# Cluster                                  4.00       4.00     4.00      4.00
#
#                                            STD      Variance
# Citation                              11169.43  1.247562e+08
# h-index                                  15.81  2.501100e+02
# i10-index                                60.81  3.697690e+03
# No. Of Publications                     243.61  5.934824e+04
# No. Of publications without citation    140.36  1.970129e+04
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                          9.29  8.639000e+01
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      2193.84  4.812936e+06
# The most citation density                 0.05  0.000000e+00
# Sum of top 10 citations                7104.87  5.047914e+07
# Sum of top 10 citations density         592.07  3.505496e+05
# Observation time window (years)         163.15  2.661883e+04
# average citation per publication         44.03  1.938220e+03
# average citation per year               345.13  1.191164e+05
# average publication per year              6.73  4.530000e+01
# Cluster                                   0.00  0.000000e+00

# %% [markdown]
# # Find minimum and maximum in all clusters

# %%
max = {}
min = {}
max_cluster = {}
min_cluster = {}
for cluster in min_max_clusters:
  for item in cluster['max']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = max.get(col, 0)
      if value > v:
        max[col] = value
        max_cluster[col] = cluster['cluster'] + 1
  for item in cluster['min']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = min.get(col, 100000000)
      if value < v:
        min[col] = value
        min_cluster[col] = cluster['cluster'] + 1

# %%
from pprint import pprint

# Most of maximums are in cluster 2
print('Max:', end="\n\n")
pprint(max_cluster, indent=2)

# Most of minimums are in cluster 3
print('\n\nMin:', end="\n\n")
pprint(min_cluster, indent=2)
# Out:
# Max:
#
# { 'Citation': 2,
#   'No. Of Publications': 2,
#   'No. Of publications without citation': 2,
#   'No.Of US pattent': 2,
#   'Observation time window (years)': 2,
#   'Patents and Publications balance': 5,
#   'Sum of top 10 citations': 2,
#   'Sum of top 10 citations density': 2,
#   'The most citation': 2,
#   'The most citation density': 3,
#   'Uncited rate': 4,
#   'average citation per publication': 3,
#   'average citation per year': 3,
#   'average publication per year': 2,
#   'h-index': 2,
#   'i10-index': 2}
#
#
# Min:
#
# { 'Citation': 3,
#   'No. Of Publications': 3,
#   'No. Of publications without citation': 2,
#   'No.Of US pattent': 1,
#   'Observation time window (years)': 3,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 3,
#   'Sum of top 10 citations density': 3,
#   'The most citation': 3,
#   'The most citation density': 2,
#   'Uncited rate': 2,
#   'average citation per publication': 4,
#   'average citation per year': 4,
#   'average publication per year': 3,
#   'h-index': 3,
#   'i10-index': 1}

# %% [markdown]
# # Implement codebook

# %%
kmeansInertias = []
kmeans = KMeans(init='k-means++', n_clusters=5, random_state=0, n_init=12) 
kmeans.fit(df)
clusterCenters = kmeans.cluster_centers_
kmeansInertias.append(kmeans.inertia_)
centroidsTable = pd.DataFrame(clusterCenters, columns=df.columns[:17], index = ['C'+str(i+1) for i in range(len(clusterCenters))])

display(centroidsTable)
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.018889  0.160786  0.042910            0.050345
# C2  0.007780  0.172511  0.051293            0.106354
# C3  0.098337  0.584163  0.296308            0.345794
# C4  0.037923  0.410725  0.177413            0.274689
# C5  0.012187  0.165122  0.045375            0.071358
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.015096     0.399312         0.001180
# C2                             0.068279     0.915829         0.001195
# C3                             0.132855     0.436195         0.014921
# C4                             0.147937     0.753461         0.006093
# C5                             0.034562     0.752694         0.001291
#
#    Patents and Publications balance The most citation  \
# C1                         0.009564          0.045460
# C2                         0.006507          0.005505
# C3                         0.022028          0.059118
# C4                         0.013806          0.022223
# C5                         0.010409          0.018521
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.845328                0.017927
# C2                  0.275286                0.004956
# C3                  0.186576                0.042795
# C4                  0.199211                0.017823
# C5                  0.588291                0.010199
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.017927                        0.025707
# C2                        0.004956                        0.036185
# C3                        0.042795                        0.057476
# C4                        0.017823                        0.050343
# C5                        0.010199                        0.032017
#
#    average citation per publication average citation per year  \
# C1                         0.041889                  0.041824
# C2                         0.009055                  0.013560
# C3                         0.038532                  0.133691
# C4                         0.020134                  0.052075
# C5                         0.018360                  0.022584
#
#    average publication per year
# C1                     0.045107
# C2                     0.068543
# C3                     0.172557
# C4                     0.142763
# C5                     0.053779

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
i = 0
j = 0
display(centroidsTable)
for col in centroidsTable.columns:
    if j == 4:
        i += 1
        j = 0
    ax[i, j].set(title = col)
    ax[i, j].plot(centroidsTable[col], linestyle = 'dotted')
    j += 1
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.018889  0.160786  0.042910            0.050345
# C2  0.007780  0.172511  0.051293            0.106354
# C3  0.098337  0.584163  0.296308            0.345794
# C4  0.037923  0.410725  0.177413            0.274689
# C5  0.012187  0.165122  0.045375            0.071358
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.015096     0.399312         0.001180
# C2                             0.068279     0.915829         0.001195
# C3                             0.132855     0.436195         0.014921
# C4                             0.147937     0.753461         0.006093
# C5                             0.034562     0.752694         0.001291
#
#    Patents and Publications balance The most citation  \
# C1                         0.009564          0.045460
# C2                         0.006507          0.005505
# C3                         0.022028          0.059118
# C4                         0.013806          0.022223
# C5                         0.010409          0.018521
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.845328                0.017927
# C2                  0.275286                0.004956
# C3                  0.186576                0.042795
# C4                  0.199211                0.017823
# C5                  0.588291                0.010199
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.017927                        0.025707
# C2                        0.004956                        0.036185
# C3                        0.042795                        0.057476
# C4                        0.017823                        0.050343
# C5                        0.010199                        0.032017
#
#    average citation per publication average citation per year  \
# C1                         0.041889                  0.041824
# C2                         0.009055                  0.013560
# C3                         0.038532                  0.133691
# C4                         0.020134                  0.052075
# C5                         0.018360                  0.022584
#
#    average publication per year
# C1                     0.045107
# C2                     0.068543
# C3                     0.172557
# C4                     0.142763
# C5                     0.053779

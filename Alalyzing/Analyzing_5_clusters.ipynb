# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# # Import dataset

# %%
df = pd.read_excel('../Data-gathering/Json/Final_Dataset.xlsx')
df = df.drop(['Index',
           'Date',
           'index',
           'Author name',
           'University',
           'country',
           'Google Scholar link of the university',
           'Google Scholar link of the author',
           'Qs uni world ranking',
           'Qs uni country ranking',
           'Date of the first publication (year)',
           'Date of the last publication (year)',
           "Author's positin in top 100 pages",
            ], axis=1)
cols = df.columns
main_df = df

# %% [markdown]
# # Minmax scaler

# %%
scaler = preprocessing.MinMaxScaler()
scaled = scaler.fit_transform(main_df)
min_maxed_df = pd.DataFrame(scaled, columns=[cols])

# %% [markdown]
# # Normalization

# %%
df_normalized = preprocessing.normalize(min_maxed_df)
dfcopy = df_normalized
df = pd.DataFrame(df_normalized, columns=[cols])

# %% [markdown]
# # PCA

# %%
Newdf = pd.DataFrame(df, columns=[cols])
pca = PCA(2)
Newdf = pca.fit_transform(df)
data = Newdf.copy()
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(data)

label = kmeans.fit_predict(data)
fig, ax = plt.subplots(figsize=(10, 10))

u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(data[label == i , 0] , data[label == i , 1] )
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(type(df))
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %% [markdown]
# # Trian model with 5 clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df)

label = kmeans.fit_predict(df)
print(label)
# Out:
# [2 2 2 ... 0 1 4]

# %% [markdown]
# # Assign clusters to dataframe

# %%
main_df['Cluster'] = label
main_df = main_df.astype({"Cluster": int})

# %% [markdown]
# # Clusters histogram

# %%
main_df['Cluster'].hist()
# Out:
# <AxesSubplot:>

# %%
cluster_groups = main_df.groupby('Cluster')

# %% [markdown]
# # Histogram of each cluster

# %%
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
  fig.suptitle(f'Cluster {cluster + 1}', fontsize=16)
  i = 0
  j = 0
  for col in group.columns:
      if j == 4:
          i += 1
          j = 0
      if col == 'Cluster':
        pass
      else:
        ax[i, j].set(title = col)
        ax[i, j].hist(group[col])
      j += 1

# %% [markdown]
# # Data summary of each cluster

# %%
min_max_clusters = []
# from sklearn.utils.fixes import threadpool_limits
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  statistical = []
  temp_min_max = {
      'cluster': cluster,
      'min': [],
      'max': [],
  }
  for col in group.columns:
      statistical_par = {
              'Minimum': round(group[col].min(),2),
              'Maximum': round(group[col].max(),2),
              'Median':  round(group[col].median(),2),
              'Mean':    round(group[col].mean(),2),
              'STD':     round(group[col].std(),2),
              'Variance':round(group[col].var(),2)
          }
      
      temp_min_max['max'].append({col:statistical_par['Maximum']})
      temp_min_max['min'].append({col:statistical_par['Minimum']})
      statistical.append(statistical_par)
  min_max_clusters.append(temp_min_max)
  temp = pd.DataFrame(
      statistical, 
      index = group.columns
  )
  print(f"\n\nCluster {cluster + 1}", end="\n")
  display(temp)
# Out:
# Cluster 1
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  176539.00  2065.50  7428.55
# h-index                                  1.00      87.00    16.00    20.15
# i10-index                                0.00     263.00    20.00    33.80
# No. Of Publications                      1.00     511.00    41.00    68.37
# No. Of publications without citation     0.00     218.00     7.00    15.14
# Uncited rate                             0.00       0.67     0.18     0.20
# No.Of US pattent                         0.00      47.00     0.00     0.46
# Patents and Publications balance         0.00       0.83     0.00     0.00
# The most citation                        1.00  126317.00   741.00  3695.47
# The most citation density                0.09       1.00     0.41     0.45
# Sum of top 10 citations                  1.00  188615.00  1733.00  6356.47
# Sum of top 10 citations density          0.08   15717.92   144.42   529.71
# Observation time window (years)          1.00    2013.00    17.00    27.72
# average citation per publication         0.50    4864.50    48.46   105.26
# average citation per year                0.42   16344.62   124.78   350.42
# average publication per year             0.01      27.55     2.42     3.23
# Cluster                                  0.00       0.00     0.00     0.00
#
#                                            STD      Variance
# Citation                              14214.52  2.020526e+08
# h-index                                  15.39  2.368700e+02
# i10-index                                38.22  1.460560e+03
# No. Of Publications                      76.53  5.856740e+03
# No. Of publications without citation     23.72  5.626100e+02
# Uncited rate                              0.13  2.000000e-02
# No.Of US pattent                          2.63  6.920000e+00
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      8628.44  7.444994e+07
# The most citation density                 0.22  5.000000e-02
# Sum of top 10 citations               14217.89  2.021485e+08
# Sum of top 10 citations density        1184.82  1.403809e+06
# Observation time window (years)         118.15  1.395999e+04
# average citation per publication        245.19  6.011632e+04
# average citation per year               811.05  6.578083e+05
# average publication per year              2.68  7.160000e+00
# Cluster                                   0.00  0.000000e+00
# Cluster 2
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                14.00  41249.00  1635.00  2464.18
# h-index                                  2.00     56.00    21.00    22.00
# i10-index                                0.00    133.00    36.00    39.93
# No. Of Publications                     10.00    892.00   118.00   141.42
# No. Of publications without citation     5.00    697.00    42.00    58.91
# Uncited rate                             0.13      0.91     0.38     0.39
# No.Of US pattent                         0.00    344.00     0.00     0.42
# Patents and Publications balance         0.00      0.95     0.00     0.00
# The most citation                        3.00   6711.00   178.00   310.05
# The most citation density                0.03      0.44     0.12     0.13
# Sum of top 10 citations                 14.00  35356.00   860.00  1347.52
# Sum of top 10 citations density          1.17   2946.33    71.67   112.29
# Observation time window (years)          3.00   2021.00    27.00    33.05
# average citation per publication         0.19    513.75    13.29    17.67
# average citation per year                0.47   3746.38    59.44    92.01
# average publication per year             0.18     32.82     4.40     5.07
# Cluster                                  1.00      1.00     1.00     1.00
#
#                                           STD    Variance
# Citation                              2945.22  8674308.97
# h-index                                  9.74       94.92
# i10-index                               24.88      618.81
# No. Of Publications                     98.59     9720.95
# No. Of publications without citation    57.81     3342.37
# Uncited rate                             0.12        0.01
# No.Of US pattent                         6.38       40.72
# Patents and Publications balance         0.02        0.00
# The most citation                      480.25   230638.77
# The most citation density                0.05        0.00
# Sum of top 10 citations               1992.40  3969669.31
# Sum of top 10 citations density        166.03    27567.15
# Observation time window (years)         55.42     3071.12
# average citation per publication        20.47      418.87
# average citation per year              153.05    23422.81
# average publication per year             3.08        9.49
# Cluster                                  0.00        0.00
# Cluster 3
#                                       Minimum    Maximum    Median      Mean  \
# Citation                               900.00  744199.00  29905.00  44381.34
# h-index                                 19.00     299.00     81.00     87.32
# i10-index                               27.00    1904.00    261.00    309.92
# No. Of Publications                     30.00    3000.00    468.00    604.57
# No. Of publications without citation     0.00    1424.00    101.00    160.17
# Uncited rate                             0.00       0.66      0.21      0.21
# No.Of US pattent                         0.00     716.00      0.00      6.84
# Patents and Publications balance         0.00       0.94      0.00      0.01
# The most citation                       50.00  126878.00   2018.00   4743.55
# The most citation density                0.01       0.40      0.07      0.09
# Sum of top 10 citations                343.00  632866.00   8715.00  16166.14
# Sum of top 10 citations density         28.58   52738.83    726.25   1347.18
# Observation time window (years)          3.00    2021.00     36.00     74.91
# average citation per publication         9.16     919.08     62.77     84.79
# average citation per year                2.84   13599.33    775.00   1209.86
# average publication per year             0.07     175.00     12.63     15.71
# Cluster                                  2.00       2.00      2.00      2.00
#
#                                            STD      Variance
# Citation                              46804.96  2.190704e+09
# h-index                                  35.32  1.247800e+03
# i10-index                               219.02  4.796921e+04
# No. Of Publications                     498.56  2.485588e+05
# No. Of publications without citation    191.96  3.684969e+04
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                         26.36  6.948500e+02
# Patents and Publications balance          0.04  0.000000e+00
# The most citation                      8217.15  6.752159e+07
# The most citation density                 0.06  0.000000e+00
# Sum of top 10 citations               24662.32  6.082298e+08
# Sum of top 10 citations density        2055.19  4.223818e+06
# Observation time window (years)         248.25  6.163015e+04
# average citation per publication         75.41  5.687020e+03
# average citation per year              1357.41  1.842555e+06
# average publication per year             12.58  1.583100e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 4
#                                       Minimum    Maximum   Median      Mean  \
# Citation                               568.00  225629.00  9722.00  12910.94
# h-index                                 10.00     150.00    49.00     51.44
# i10-index                               12.00     503.00   130.00    144.40
# No. Of Publications                     43.00    2527.00   315.00    381.23
# No. Of publications without citation     5.00    1807.00    94.00    138.14
# Uncited rate                             0.07       0.94     0.29      0.31
# No.Of US pattent                         0.00     120.00     0.00      2.09
# Patents and Publications balance         0.00       0.27     0.00      0.01
# The most citation                       22.00   44738.00   682.50   1357.93
# The most citation density                0.01       0.43     0.08      0.09
# Sum of top 10 citations                186.00  214306.00  3236.50   5183.93
# Sum of top 10 citations density         15.50   17858.83   269.71    431.99
# Observation time window (years)          1.00    2021.00    34.00     47.67
# average citation per publication         1.24    1683.80    30.18     38.76
# average citation per year                1.29    6267.47   275.20    371.74
# average publication per year             0.07     145.86     9.11     10.80
# Cluster                                  3.00       3.00     3.00      3.00
#
#                                            STD      Variance
# Citation                              11647.01  1.356528e+08
# h-index                                  16.58  2.749000e+02
# i10-index                                65.93  4.347190e+03
# No. Of Publications                     261.45  6.835850e+04
# No. Of publications without citation    152.12  2.313900e+04
# Uncited rate                              0.11  1.000000e-02
# No.Of US pattent                          7.30  5.327000e+01
# Patents and Publications balance          0.02  0.000000e+00
# The most citation                      2274.97  5.175480e+06
# The most citation density                 0.05  0.000000e+00
# Sum of top 10 citations                7197.44  5.180320e+07
# Sum of top 10 citations density         599.79  3.597444e+05
# Observation time window (years)         123.29  1.519956e+04
# average citation per publication         43.28  1.873580e+03
# average citation per year               368.21  1.355817e+05
# average publication per year              7.52  5.650000e+01
# Cluster                                   0.00  0.000000e+00
# Cluster 5
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  104130.00  1398.00  3979.11
# h-index                                  1.00      87.00    17.00    19.63
# i10-index                                0.00     247.00    23.00    33.15
# No. Of Publications                      5.00     903.00    62.00    89.59
# No. Of publications without citation     2.00     506.00    18.00    29.32
# Uncited rate                             0.06       0.96     0.31     0.32
# No.Of US pattent                         0.00      33.00     0.00     0.38
# Patents and Publications balance         0.00       0.43     0.00     0.00
# The most citation                        1.00   42314.00   308.00  1152.76
# The most citation density                0.08       1.00     0.25     0.28
# Sum of top 10 citations                  1.00   91469.00   995.00  2911.86
# Sum of top 10 citations density          0.08    7622.42    82.92   242.65
# Observation time window (years)          2.00    2021.00    22.00    29.13
# average citation per publication         0.10     706.31    21.71    35.08
# average citation per year                0.10    4120.17    64.84   151.25
# average publication per year             0.04      26.15     2.98     3.66
# Cluster                                  4.00       4.00     4.00     4.00
#
#                                           STD     Variance
# Citation                              7847.91  61589620.31
# h-index                                 12.74       162.37
# i10-index                               32.43      1051.63
# No. Of Publications                     86.50      7483.06
# No. Of publications without citation    37.12      1377.89
# Uncited rate                             0.13         0.02
# No.Of US pattent                         1.86         3.45
# Patents and Publications balance         0.02         0.00
# The most citation                     2747.70   7549861.64
# The most citation density                0.13         0.02
# Sum of top 10 citations               6421.42  41234573.19
# Sum of top 10 citations density        535.12    286351.20
# Observation time window (years)         82.33      6778.62
# average citation per publication        46.91      2200.50
# average citation per year              278.07     77321.55
# average publication per year             2.64         6.95
# Cluster                                  0.00         0.00

# %% [markdown]
# # Find minimum and maximum in all clusters

# %%
max = {}
min = {}
max_cluster = {}
min_cluster = {}
for cluster in min_max_clusters:
  for item in cluster['max']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = max.get(col, 0)
      if value > v:
        max[col] = value
        max_cluster[col] = cluster['cluster'] + 1
  for item in cluster['min']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = min.get(col, 100000000)
      if value < v:
        min[col] = value
        min_cluster[col] = cluster['cluster'] + 1

# %%
from pprint import pprint

# Most of maximums are in cluster 2
print('Max:', end="\n\n")
pprint(max_cluster, indent=2)

# Most of minimums are in cluster 3
print('\n\nMin:', end="\n\n")
pprint(min_cluster, indent=2)
# Out:
# Max:
#
# { 'Citation': 3,
#   'No. Of Publications': 3,
#   'No. Of publications without citation': 4,
#   'No.Of US pattent': 3,
#   'Observation time window (years)': 2,
#   'Patents and Publications balance': 2,
#   'Sum of top 10 citations': 3,
#   'Sum of top 10 citations density': 3,
#   'The most citation': 3,
#   'The most citation density': 1,
#   'Uncited rate': 5,
#   'average citation per publication': 1,
#   'average citation per year': 1,
#   'average publication per year': 3,
#   'h-index': 3,
#   'i10-index': 3}
#
#
# Min:
#
# { 'Citation': 1,
#   'No. Of Publications': 1,
#   'No. Of publications without citation': 1,
#   'No.Of US pattent': 1,
#   'Observation time window (years)': 1,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 1,
#   'Sum of top 10 citations density': 1,
#   'The most citation': 1,
#   'The most citation density': 3,
#   'Uncited rate': 1,
#   'average citation per publication': 5,
#   'average citation per year': 5,
#   'average publication per year': 1,
#   'h-index': 1,
#   'i10-index': 1}

# %% [markdown]
# # Implement codebook

# %%
kmeansInertias = []
kmeans = KMeans(init='k-means++', n_clusters=5, random_state=0, n_init=12) 
kmeans.fit(df)
clusterCenters = kmeans.cluster_centers_
kmeansInertias.append(kmeans.inertia_)
centroidsTable = pd.DataFrame(clusterCenters, columns=df.columns[:17], index = ['C'+str(i+1) for i in range(len(clusterCenters))])

display(centroidsTable)
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.018889  0.160786  0.042910            0.050345
# C2  0.007780  0.172511  0.051293            0.106354
# C3  0.098337  0.584163  0.296308            0.345794
# C4  0.037923  0.410725  0.177413            0.274689
# C5  0.012187  0.165122  0.045375            0.071358
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.015096     0.399312         0.001180
# C2                             0.068279     0.915829         0.001195
# C3                             0.132855     0.436195         0.014921
# C4                             0.147937     0.753461         0.006093
# C5                             0.034562     0.752694         0.001291
#
#    Patents and Publications balance The most citation  \
# C1                         0.009564          0.045460
# C2                         0.006507          0.005505
# C3                         0.022028          0.059118
# C4                         0.013806          0.022223
# C5                         0.010409          0.018521
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.845328                0.017927
# C2                  0.275286                0.004956
# C3                  0.186576                0.042795
# C4                  0.199211                0.017823
# C5                  0.588291                0.010199
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.017927                        0.025707
# C2                        0.004956                        0.036185
# C3                        0.042795                        0.057476
# C4                        0.017823                        0.050343
# C5                        0.010199                        0.032017
#
#    average citation per publication average citation per year  \
# C1                         0.041889                  0.041824
# C2                         0.009055                  0.013560
# C3                         0.038532                  0.133691
# C4                         0.020134                  0.052075
# C5                         0.018360                  0.022584
#
#    average publication per year
# C1                     0.045107
# C2                     0.068543
# C3                     0.172557
# C4                     0.142763
# C5                     0.053779

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
i = 0
j = 0
display(centroidsTable)
for col in centroidsTable.columns:
    if j == 4:
        i += 1
        j = 0
    ax[i, j].set(title = col)
    ax[i, j].plot(centroidsTable[col], linestyle = 'dotted')
    j += 1
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.018889  0.160786  0.042910            0.050345
# C2  0.007780  0.172511  0.051293            0.106354
# C3  0.098337  0.584163  0.296308            0.345794
# C4  0.037923  0.410725  0.177413            0.274689
# C5  0.012187  0.165122  0.045375            0.071358
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.015096     0.399312         0.001180
# C2                             0.068279     0.915829         0.001195
# C3                             0.132855     0.436195         0.014921
# C4                             0.147937     0.753461         0.006093
# C5                             0.034562     0.752694         0.001291
#
#    Patents and Publications balance The most citation  \
# C1                         0.009564          0.045460
# C2                         0.006507          0.005505
# C3                         0.022028          0.059118
# C4                         0.013806          0.022223
# C5                         0.010409          0.018521
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.845328                0.017927
# C2                  0.275286                0.004956
# C3                  0.186576                0.042795
# C4                  0.199211                0.017823
# C5                  0.588291                0.010199
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.017927                        0.025707
# C2                        0.004956                        0.036185
# C3                        0.042795                        0.057476
# C4                        0.017823                        0.050343
# C5                        0.010199                        0.032017
#
#    average citation per publication average citation per year  \
# C1                         0.041889                  0.041824
# C2                         0.009055                  0.013560
# C3                         0.038532                  0.133691
# C4                         0.020134                  0.052075
# C5                         0.018360                  0.022584
#
#    average publication per year
# C1                     0.045107
# C2                     0.068543
# C3                     0.172557
# C4                     0.142763
# C5                     0.053779

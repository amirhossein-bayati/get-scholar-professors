# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# # Import dataset

# %%
df = pd.read_excel('../Data-gathering/Json/Final_Dataset.xlsx')
df = df.drop(['Index',
           'Date',
           'index',
           'Author name',
           'University',
           'country',
           'Google Scholar link of the university',
           'Google Scholar link of the author',
           'Qs uni world ranking',
           'Qs uni country ranking',
           'Date of the first publication (year)',
           'Date of the last publication (year)',
            ], axis=1)
cols = df.columns
main_df = df

# %% [markdown]
# # Minmax scaler

# %%
scaler = preprocessing.MinMaxScaler()
scaled = scaler.fit_transform(main_df)
min_maxed_df = pd.DataFrame(scaled, columns=[cols])

# %% [markdown]
# # Normalization

# %%
df_normalized = preprocessing.normalize(min_maxed_df)
dfcopy = df_normalized
df = pd.DataFrame(df_normalized, columns=[cols])

# %% [markdown]
# # PCA

# %%
pca = PCA(2)
data = pca.fit_transform(df)
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(data)

label = kmeans.fit_predict(data)
fig, ax = plt.subplots(figsize=(10, 10))

u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(data[label == i , 0] , data[label == i , 1] )
plt.show()

# %% [markdown]
# # Trian model with 5 clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df)

label = kmeans.fit_predict(df)
print(label)
# Out:
# [3 3 3 ... 1 1 1]

# %% [markdown]
# # Assign clusters to dataframe

# %%
main_df['Cluster'] = label
main_df = main_df.astype({"Cluster": int})

# %% [markdown]
# # Export dataset with label column

# %%
main_df.to_excel('Labled_Dataset_With_Author_Rank.xlsx')

# %% [markdown]
# # Clusters histogram

# %%
main_df['Cluster'].hist()
# Out:
# <AxesSubplot:>

# %%
cluster_groups = main_df.groupby('Cluster')

# %% [markdown]
# # Histogram of each cluster

# %%
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  fig, ax = plt.subplots(nrows=5, ncols=4, figsize=(20, 20))
  fig.suptitle(f'Cluster {cluster + 1}', fontsize=16)
  i = 0
  j = 0
  for col in group.columns:
      if j == 4:
          i += 1
          j = 0
      if col == 'Cluster':
        pass
      else:
        ax[i, j].set(title = col)
        ax[i, j].hist(group[col])
      j += 1

# %% [markdown]
# # Data summary of each cluster

# %%
min_max_clusters = []
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  statistical = []
  temp_min_max = {
      'cluster': cluster,
      'min': [],
      'max': [],
  }
  for col in group.columns:
      statistical_par = {
              'Minimum': round(group[col].min(),2),
              'Maximum': round(group[col].max(),2),
              'Median':  round(group[col].median(),2),
              'Mean':    round(group[col].mean(),2),
              'STD':     round(group[col].std(),2),
              'Variance':round(group[col].var(),2)
          }
      
      temp_min_max['max'].append({col:statistical_par['Maximum']})
      temp_min_max['min'].append({col:statistical_par['Minimum']})
      statistical.append(statistical_par)
  min_max_clusters.append(temp_min_max)
  temp = pd.DataFrame(
      statistical, 
      index = group.columns
  )
  print(f"\n\nCluster {cluster + 1}", end="\n")
  display(temp)
# Out:
# Cluster 1
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  176539.00  2063.50  7566.77
# h-index                                  1.00      96.00    15.00    19.67
# i10-index                                0.00     293.00    18.00    33.72
# No. Of Publications                      1.00     577.00    49.00    78.66
# No. Of publications without citation     0.00     261.00    13.00    22.80
# Uncited rate                             0.00       0.96     0.29     0.30
# No.Of US pattent                         0.00      45.00     0.00     0.37
# Patents and Publications balance         0.00       0.53     0.00     0.00
# The most citation                        1.00  126317.00   818.50  3805.86
# The most citation density                0.11       1.00     0.46     0.49
# Sum of top 10 citations                  1.00  188615.00  1799.00  6460.19
# Sum of top 10 citations density          0.08   15717.92   149.92   538.35
# Observation time window (years)          1.00    2016.00    20.00    31.60
# average citation per publication         0.10    4864.50    41.19    96.29
# average citation per year                0.10   16344.62   106.80   339.35
# average publication per year             0.01      26.15     2.60     3.34
# Author's positin in top 100 pages        1.00     100.00    38.00    41.22
# Cluster                                  0.00       0.00     0.00     0.00
#
#                                            STD      Variance
# Citation                              14318.70  2.050252e+08
# h-index                                  15.94  2.540800e+02
# i10-index                                40.25  1.619810e+03
# No. Of Publications                      84.97  7.219210e+03
# No. Of publications without citation     28.79  8.287700e+02
# Uncited rate                              0.16  3.000000e-02
# No.Of US pattent                          2.11  4.450000e+00
# Patents and Publications balance          0.02  0.000000e+00
# The most citation                      8570.91  7.346043e+07
# The most citation density                 0.21  4.000000e-02
# Sum of top 10 citations               14135.62  1.998156e+08
# Sum of top 10 citations density        1177.97  1.387608e+06
# Observation time window (years)         130.05  1.691416e+04
# average citation per publication        237.37  5.634403e+04
# average citation per year               819.61  6.717538e+05
# average publication per year              2.72  7.390000e+00
# Author's positin in top 100 pages        24.04  5.780200e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 2
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                 6.00  74313.00  2735.50  6223.85
# h-index                                  2.00    126.00    25.00    30.83
# i10-index                                0.00    660.00    46.00    69.65
# No. Of Publications                      2.00   1177.00   108.00   151.94
# No. Of publications without citation     0.00    359.00    25.00    39.07
# Uncited rate                             0.00      0.60     0.25     0.25
# No.Of US pattent                         0.00    367.00     0.00     1.10
# Patents and Publications balance         0.00      0.94     0.00     0.01
# The most citation                        2.00  21709.00   299.50   809.77
# The most citation density                0.02      0.65     0.13     0.16
# Sum of top 10 citations                  6.00  47403.00  1332.00  2852.58
# Sum of top 10 citations density          0.50   3950.25   111.00   237.72
# Observation time window (years)          1.00   2021.00    24.00    30.08
# average citation per publication         0.96   1944.00    24.23    37.85
# average citation per year                0.47   7057.50   113.87   222.47
# average publication per year             0.07    101.00     4.42     5.65
# Author's positin in top 100 pages       15.00    100.00    78.00    75.73
# Cluster                                  1.00      1.00     1.00     1.00
#
#                                           STD     Variance
# Citation                              9177.33  84223461.91
# h-index                                 20.69       428.17
# i10-index                               69.36      4811.41
# No. Of Publications                    138.46     19170.45
# No. Of publications without citation    41.25      1701.16
# Uncited rate                             0.11         0.01
# No.Of US pattent                         7.33        53.72
# Patents and Publications balance         0.03         0.00
# The most citation                     1612.30   2599499.28
# The most citation density                0.10         0.01
# Sum of top 10 citations               4570.38  20888410.96
# Sum of top 10 citations density        380.87    145058.41
# Observation time window (years)         62.14      3861.18
# average citation per publication        56.18      3156.59
# average citation per year              344.57    118726.61
# average publication per year             4.65        21.60
# Author's positin in top 100 pages       17.00       288.93
# Cluster                                  0.00         0.00
# Cluster 3
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 7.00  225629.00  4361.00  8045.40
# h-index                                  2.00      92.00    31.00    33.16
# i10-index                                0.00     286.00    63.00    73.98
# No. Of Publications                      7.00    1846.00   183.50   244.25
# No. Of publications without citation     4.00    1358.00    64.50   104.84
# Uncited rate                             0.10       0.94     0.38     0.39
# No.Of US pattent                         0.00      56.00     0.00     0.74
# Patents and Publications balance         0.00       0.18     0.00     0.00
# The most citation                        3.00   55520.00   474.50  1507.52
# The most citation density                0.01       0.62     0.13     0.16
# Sum of top 10 citations                  7.00  214306.00  1974.50  4774.55
# Sum of top 10 citations density          0.58   17858.83   164.54   397.88
# Observation time window (years)          4.00    2008.00    32.00    41.94
# average citation per publication         0.21    1683.80    22.05    37.73
# average citation per year                0.67    6267.47   129.69   255.33
# average publication per year             0.11      56.23     5.67     6.95
# Author's positin in top 100 pages        1.00      61.00    16.00    16.61
# Cluster                                  2.00       2.00     2.00     2.00
#
#                                            STD      Variance
# Citation                              12371.86  1.530629e+08
# h-index                                  15.98  2.552400e+02
# i10-index                                49.34  2.434200e+03
# No. Of Publications                     208.12  4.331277e+04
# No. Of publications without citation    130.15  1.693814e+04
# Uncited rate                              0.12  2.000000e-02
# No.Of US pattent                          3.11  9.650000e+00
# Patents and Publications balance          0.01  0.000000e+00
# The most citation                      3651.28  1.333183e+07
# The most citation density                 0.09  1.000000e-02
# Sum of top 10 citations               10306.31  1.062200e+08
# Sum of top 10 citations density         858.86  7.376388e+05
# Observation time window (years)          79.11  6.258010e+03
# average citation per publication         67.28  4.526390e+03
# average citation per year               439.00  1.927191e+05
# average publication per year              5.26  2.766000e+01
# Author's positin in top 100 pages         9.75  9.512000e+01
# Cluster                                   0.00  0.000000e+00
# Cluster 4
#                                       Minimum    Maximum    Median      Mean  \
# Citation                              2252.00  744199.00  33200.00  48693.31
# h-index                                 27.00     299.00     85.00     91.35
# i10-index                               49.00    1904.00    282.00    339.40
# No. Of Publications                     68.00    3000.00    589.00    733.63
# No. Of publications without citation     0.00    1807.00    157.00    229.12
# Uncited rate                             0.00       0.81      0.27      0.27
# No.Of US pattent                         0.00     716.00      0.00      6.74
# Patents and Publications balance         0.00       0.34      0.00      0.01
# The most citation                       94.00  126878.00   2213.00   5260.61
# The most citation density                0.01       0.43      0.07      0.09
# Sum of top 10 citations                713.00  632866.00   9680.00  17707.03
# Sum of top 10 citations density         59.42   52738.83    806.67   1475.59
# Observation time window (years)          3.00    2021.00     39.00     77.80
# average citation per publication         3.09     919.08     55.74     77.62
# average citation per year                2.84   13599.33    813.37   1273.88
# average publication per year             0.13     175.00     14.92     18.13
# Author's positin in top 100 pages        1.00      89.00     13.00     15.56
# Cluster                                  3.00       3.00      3.00      3.00
#
#                                            STD      Variance
# Citation                              49471.20  2.447399e+09
# h-index                                  35.51  1.260840e+03
# i10-index                               222.35  4.943834e+04
# No. Of Publications                     517.09  2.673820e+05
# No. Of publications without citation    226.61  5.135090e+04
# Uncited rate                              0.12  1.000000e-02
# No.Of US pattent                         26.02  6.770500e+02
# Patents and Publications balance          0.02  0.000000e+00
# The most citation                      8828.98  7.795083e+07
# The most citation density                 0.07  0.000000e+00
# Sum of top 10 citations               26478.59  7.011158e+08
# Sum of top 10 citations density        2206.55  4.868860e+06
# Observation time window (years)         244.30  5.968292e+04
# average citation per publication         76.40  5.836680e+03
# average citation per year              1427.75  2.038467e+06
# average publication per year             13.75  1.890000e+02
# Author's positin in top 100 pages        12.44  1.548000e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 5
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                 9.00  72499.00  4218.50  8128.75
# h-index                                  2.00    127.00    33.00    36.68
# i10-index                                0.00    507.00    71.00    93.34
# No. Of Publications                      6.00   1669.00   197.00   256.69
# No. Of publications without citation     3.00   1042.00    65.00    95.22
# Uncited rate                             0.07      0.88     0.36     0.37
# No.Of US pattent                         0.00    344.00     0.00     1.67
# Patents and Publications balance         0.00      0.95     0.00     0.01
# The most citation                        3.00  19945.00   368.50   903.20
# The most citation density                0.02      0.55     0.11     0.13
# Sum of top 10 citations                  9.00  79276.00  1718.50  3381.22
# Sum of top 10 citations density          0.75   6606.33   143.21   281.77
# Observation time window (years)          3.00   2021.00    30.00    45.95
# average citation per publication         0.19    400.97    20.47    28.84
# average citation per year                0.67   6758.00   132.39   241.62
# average publication per year             0.07     60.63     6.35     7.82
# Author's positin in top 100 pages       14.00    100.00    47.00    49.73
# Cluster                                  4.00      4.00     4.00     4.00
#
#                                            STD      Variance
# Citation                              10350.84  1.071398e+08
# h-index                                  22.54  5.080300e+02
# i10-index                                81.03  6.565380e+03
# No. Of Publications                     213.86  4.573819e+04
# No. Of publications without citation     99.21  9.843420e+03
# Uncited rate                              0.13  2.000000e-02
# No.Of US pattent                          9.87  9.742000e+01
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      1698.22  2.883952e+06
# The most citation density                 0.08  1.000000e-02
# Sum of top 10 citations                5009.74  2.509752e+07
# Sum of top 10 citations density         417.48  1.742883e+05
# Observation time window (years)         145.24  2.109556e+04
# average citation per publication         31.12  9.684700e+02
# average citation per year               330.47  1.092082e+05
# average publication per year              5.93  3.518000e+01
# Author's positin in top 100 pages        17.61  3.101400e+02
# Cluster                                   0.00  0.000000e+00

# %% [markdown]
# # Find minimum and maximum in all clusters

# %%
max = {}
min = {}
max_cluster = {}
min_cluster = {}
for cluster in min_max_clusters:
  for item in cluster['max']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = max.get(col, 0)
      if value > v:
        max[col] = value
        max_cluster[col] = cluster['cluster'] + 1
  for item in cluster['min']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = min.get(col, 100000000)
      if value < v:
        min[col] = value
        min_cluster[col] = cluster['cluster'] + 1

# %%
from pprint import pprint

# Most of maximums are in cluster 4
print('Max:', end="\n\n")
pprint(max_cluster, indent=2)

# Most of minimums are in cluster 1
print('\n\nMin:', end="\n\n")
pprint(min_cluster, indent=2)
# Out:
# Max:
#
# { "Author's positin in top 100 pages": 1,
#   'Citation': 4,
#   'No. Of Publications': 4,
#   'No. Of publications without citation': 4,
#   'No.Of US pattent': 4,
#   'Observation time window (years)': 2,
#   'Patents and Publications balance': 5,
#   'Sum of top 10 citations': 4,
#   'Sum of top 10 citations density': 4,
#   'The most citation': 4,
#   'The most citation density': 1,
#   'Uncited rate': 1,
#   'average citation per publication': 1,
#   'average citation per year': 1,
#   'average publication per year': 4,
#   'h-index': 4,
#   'i10-index': 4}
#
#
# Min:
#
# { "Author's positin in top 100 pages": 1,
#   'Citation': 1,
#   'No. Of Publications': 1,
#   'No. Of publications without citation': 1,
#   'No.Of US pattent': 1,
#   'Observation time window (years)': 1,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 1,
#   'Sum of top 10 citations density': 1,
#   'The most citation': 1,
#   'The most citation density': 3,
#   'Uncited rate': 1,
#   'average citation per publication': 1,
#   'average citation per year': 1,
#   'average publication per year': 1,
#   'h-index': 1,
#   'i10-index': 1}

# %% [markdown]
# # Implement codebook

# %%
clusterCenters = kmeans.cluster_centers_
kmeansInertias.append(kmeans.inertia_)
centroidsTable = pd.DataFrame(clusterCenters, columns=df.columns[:18], index = ['C'+str(i+1) for i in range(len(clusterCenters))])

display(centroidsTable)
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.015221  0.106919  0.030090            0.041063
# C2  0.010309  0.126563  0.045705            0.061145
# C3  0.020902  0.227818  0.080892            0.153356
# C4  0.092828  0.496206  0.271066            0.355722
# C5  0.016697  0.192936  0.077631            0.127248
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.017774     0.421693         0.000789
# C2                             0.024885     0.309540         0.001767
# C3                             0.099784     0.787662         0.001981
# C4                             0.169837     0.467157         0.012424
# C5                             0.072623     0.567049         0.003312
#
#    Patents and Publications balance The most citation  \
# C1                         0.005740          0.039245
# C2                         0.006378          0.007702
# C3                         0.006920          0.021130
# C4                         0.014720          0.056999
# C5                         0.008734          0.010640
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.639576                0.014657
# C2                  0.180587                0.005575
# C3                  0.294400                0.014192
# C4                  0.142039                0.040280
# C5                  0.180832                0.008231
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.014657                        0.020581
# C2                        0.005575                        0.017422
# C3                        0.014192                        0.039098
# C4                        0.040280                        0.051042
# C5                        0.008231                        0.030777
#
#    average citation per publication average citation per year  \
# C1                         0.028248                  0.030534
# C2                         0.010055                  0.017328
# C3                         0.016459                  0.031503
# C4                         0.027938                  0.117461
# C5                         0.009963                  0.023581
#
#    average publication per year Author's positin in top 100 pages
# C1                     0.030495                          0.521171
# C2                     0.040239                          0.894323
# C3                     0.079834                          0.304096
# C4                     0.162062                          0.249679
# C5                     0.069514                          0.710174

# %%
fig, ax = plt.subplots(nrows=5, ncols=4, figsize=(20, 20))
i = 0
j = 0
display(centroidsTable)
for col in centroidsTable.columns:
    if j == 4:
        i += 1
        j = 0
    ax[i, j].set(title = col)
    ax[i, j].plot(centroidsTable[col], linestyle = 'dotted')
    j += 1
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.015221  0.106919  0.030090            0.041063
# C2  0.010309  0.126563  0.045705            0.061145
# C3  0.020902  0.227818  0.080892            0.153356
# C4  0.092828  0.496206  0.271066            0.355722
# C5  0.016697  0.192936  0.077631            0.127248
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.017774     0.421693         0.000789
# C2                             0.024885     0.309540         0.001767
# C3                             0.099784     0.787662         0.001981
# C4                             0.169837     0.467157         0.012424
# C5                             0.072623     0.567049         0.003312
#
#    Patents and Publications balance The most citation  \
# C1                         0.005740          0.039245
# C2                         0.006378          0.007702
# C3                         0.006920          0.021130
# C4                         0.014720          0.056999
# C5                         0.008734          0.010640
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.639576                0.014657
# C2                  0.180587                0.005575
# C3                  0.294400                0.014192
# C4                  0.142039                0.040280
# C5                  0.180832                0.008231
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.014657                        0.020581
# C2                        0.005575                        0.017422
# C3                        0.014192                        0.039098
# C4                        0.040280                        0.051042
# C5                        0.008231                        0.030777
#
#    average citation per publication average citation per year  \
# C1                         0.028248                  0.030534
# C2                         0.010055                  0.017328
# C3                         0.016459                  0.031503
# C4                         0.027938                  0.117461
# C5                         0.009963                  0.023581
#
#    average publication per year Author's positin in top 100 pages
# C1                     0.030495                          0.521171
# C2                     0.040239                          0.894323
# C3                     0.079834                          0.304096
# C4                     0.162062                          0.249679
# C5                     0.069514                          0.710174

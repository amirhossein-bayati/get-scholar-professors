# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# # Import dataset

# %%
df = pd.read_excel('../Data-gathering/Json/Final_Dataset.xlsx')
df = df.drop(['Index',
           'Date',
           'index',
           'Author name',
           'University',
           'country',
           'Google Scholar link of the university',
           'Google Scholar link of the author',
           'Qs uni world ranking',
           'Qs uni country ranking',
           'Date of the first publication (year)',
           'Date of the last publication (year)',
           "Author's positin in top 100 pages",
            ], axis=1)
cols = df.columns
main_df = df

# %% [markdown]
# # Minmax scaler

# %%
scaler = preprocessing.MinMaxScaler()
scaled = scaler.fit_transform(main_df)
min_maxed_df = pd.DataFrame(scaled, columns=[cols])

# %% [markdown]
# # Normalization

# %%
df_normalized = preprocessing.normalize(min_maxed_df)
dfcopy = df_normalized
df = pd.DataFrame(df_normalized, columns=[cols])

# %% [markdown]
# # PCA

# %%
Newdf = pd.DataFrame(df, columns=[cols])
pca = PCA(2)
Newdf = pca.fit_transform(df)
data = Newdf.copy()
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(data)

label = kmeans.fit_predict(data)
fig, ax = plt.subplots(figsize=(10, 10))

u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(data[label == i , 0] , data[label == i , 1] )
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# No handles with labels found to put in legend.

# %% [markdown]
# # Trian model with 6 clusters

# %%
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(df)

label = kmeans.fit_predict(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %% [markdown]
# # Assign clusters to dataframe

# %%
main_df['Cluster'] = label
main_df = main_df.astype({"Cluster": int})

# %% [markdown]
# # Clusters histogram

# %%
main_df['Cluster'].hist()

# %%
cluster_groups = main_df.groupby('Cluster')

# %% [markdown]
# # Histogram of each cluster

# %%
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
  fig.suptitle(f'Cluster {cluster + 1}', fontsize=16)
  i = 0
  j = 0
  for col in group.columns:
      if j == 4:
          i += 1
          j = 0
      if col == 'Cluster':
        pass
      else:
        ax[i, j].set(title = col)
        ax[i, j].hist(group[col])
      j += 1

# %% [markdown]
# # Data summary of each cluster

# %%
min_max_clusters = []
from sklearn.utils.fixes import threadpool_limits
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  statistical = []
  temp_min_max = {
      'cluster': cluster,
      'min': [],
      'max': [],
  }
  for col in group.columns:
      statistical_par = {
              'Minimum': round(group[col].min(),2),
              'Maximum': round(group[col].max(),2),
              'Median':  round(group[col].median(),2),
              'Mean':    round(group[col].mean(),2),
              'STD':     round(group[col].std(),2),
              'Variance':round(group[col].var(),2)
          }
      
      temp_min_max['max'].append({col:statistical_par['Maximum']})
      temp_min_max['min'].append({col:statistical_par['Minimum']})
      statistical.append(statistical_par)
  min_max_clusters.append(temp_min_max)
  temp = pd.DataFrame(
      statistical, 
      index = group.columns
  )
  print(f"\n\nCluster {cluster + 1}", end="\n")
  display(temp)
# Out:
# Cluster 1
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                20.00  41249.00  1881.00  2826.46
# h-index                                  2.00     69.00    23.00    23.53
# i10-index                                0.00    139.00    41.00    44.19
# No. Of Publications                     18.00   1443.00   126.00   153.73
# No. Of publications without citation     6.00   1358.00    44.00    63.53
# Uncited rate                             0.13      0.94     0.37     0.39
# No.Of US pattent                         0.00     28.00     0.00     0.36
# Patents and Publications balance         0.00      0.18     0.00     0.00
# The most citation                        3.00   8484.00   200.00   364.70
# The most citation density                0.03      0.39     0.12     0.12
# Sum of top 10 citations                 16.00  35356.00   962.50  1531.57
# Sum of top 10 citations density          1.33   2946.33    80.21   127.63
# Observation time window (years)          3.00   2020.00    27.00    33.19
# average citation per publication         0.19    513.75    14.11    18.80
# average citation per year                0.67   3746.38    67.64   102.46
# average publication per year             0.19     34.36     4.67     5.36
# Cluster                                  0.00      0.00     0.00     0.00
#
#                                           STD     Variance
# Citation                              3302.19  10904481.75
# h-index                                 10.00        99.98
# i10-index                               26.16       684.37
# No. Of Publications                    109.53     11996.42
# No. Of publications without citation    68.62      4708.95
# Uncited rate                             0.12         0.01
# No.Of US pattent                         1.64         2.68
# Patents and Publications balance         0.01         0.00
# The most citation                      594.18    353050.78
# The most citation density                0.05         0.00
# Sum of top 10 citations               2245.53   5042404.95
# Sum of top 10 citations density        187.13     35016.70
# Observation time window (years)         42.22      1782.25
# average citation per publication        21.06       443.47
# average citation per year              158.65     25169.30
# average publication per year             3.20        10.24
# Cluster                                  0.00         0.00
# Cluster 2
#                                       Minimum    Maximum   Median      Mean  \
# Citation                               568.00  121883.00  9965.00  12764.91
# h-index                                 10.00     150.00    51.00     52.54
# i10-index                               12.00     503.00   138.00    149.85
# No. Of Publications                     64.00    2236.00   334.00    398.31
# No. Of publications without citation     8.00    1424.00   101.00    145.75
# Uncited rate                             0.09       0.82     0.30      0.32
# No.Of US pattent                         0.00     344.00     0.00      2.26
# Patents and Publications balance         0.00       0.95     0.00      0.01
# The most citation                       22.00   21779.00   637.00   1134.44
# The most citation density                0.01       0.37     0.07      0.08
# Sum of top 10 citations                186.00   74438.00  3174.00   4745.05
# Sum of top 10 citations density         15.50    6203.17   264.50    395.42
# Observation time window (years)          1.00    2021.00    35.00     46.88
# average citation per publication         1.28     340.11    29.03     35.53
# average citation per year                1.41    5786.14   276.92    361.59
# average publication per year             0.10     145.86     9.53     11.17
# Cluster                                  1.00       1.00     1.00      1.00
#
#                                            STD      Variance
# Citation                              10579.29  1.119214e+08
# h-index                                  16.39  2.686600e+02
# i10-index                                63.52  4.034820e+03
# No. Of Publications                     258.02  6.657659e+04
# No. Of publications without citation    150.82  2.274742e+04
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                          9.79  9.577000e+01
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      1649.17  2.719758e+06
# The most citation density                 0.04  0.000000e+00
# Sum of top 10 citations                5479.33  3.002311e+07
# Sum of top 10 citations density         456.61  2.084938e+05
# Observation time window (years)         111.00  1.232193e+04
# average citation per publication         25.60  6.551600e+02
# average citation per year               339.70  1.153949e+05
# average publication per year              7.64  5.835000e+01
# Cluster                                   0.00  0.000000e+00
# Cluster 3
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  165623.00  1714.00  5791.53
# h-index                                  1.00      87.00    14.00    17.60
# i10-index                                0.00     179.00    17.00    27.46
# No. Of Publications                      1.00     486.00    37.00    59.41
# No. Of publications without citation     0.00     190.00     6.00    14.31
# Uncited rate                             0.00       0.70     0.19     0.21
# No.Of US pattent                         0.00      47.00     0.00     0.32
# Patents and Publications balance         0.00       0.31     0.00     0.00
# The most citation                        1.00  126317.00   642.00  3162.73
# The most citation density                0.11       1.00     0.43     0.47
# Sum of top 10 citations                  1.00  188615.00  1412.00  5174.41
# Sum of top 10 citations density          0.08   15717.92   117.67   431.20
# Observation time window (years)          1.00    2013.00    17.00    24.53
# average citation per publication         0.50    4864.50    43.87    97.07
# average citation per year                0.42   16344.62   104.15   285.79
# average publication per year             0.01      15.57     2.25     2.90
# Cluster                                  2.00       2.00     2.00     2.00
#
#                                            STD      Variance
# Citation                              11216.93  1.258196e+08
# h-index                                  12.68  1.607400e+02
# i10-index                                28.85  8.322500e+02
# No. Of Publications                      63.63  4.048210e+03
# No. Of publications without citation     22.14  4.902200e+02
# Uncited rate                              0.14  2.000000e-02
# No.Of US pattent                          1.88  3.530000e+00
# Patents and Publications balance          0.02  0.000000e+00
# The most citation                      7578.78  5.743795e+07
# The most citation density                 0.22  5.000000e-02
# Sum of top 10 citations               12102.47  1.464697e+08
# Sum of top 10 citations density        1008.54  1.017151e+06
# Observation time window (years)          92.39  8.535190e+03
# average citation per publication        233.71  5.461804e+04
# average citation per year               652.62  4.259117e+05
# average publication per year              2.19  4.800000e+00
# Cluster                                   0.00  0.000000e+00
# Cluster 4
#                                       Minimum    Maximum    Median      Mean  \
# Citation                               598.00  269560.00  11913.00  19624.38
# h-index                                 11.00     123.00     45.00     47.10
# i10-index                               14.00     436.00     93.00    106.14
# No. Of Publications                     30.00    1061.00    170.50    212.40
# No. Of publications without citation     0.00     614.00     31.50     53.29
# Uncited rate                             0.00       0.58      0.19      0.20
# No.Of US pattent                         0.00     105.00      0.00      1.66
# Patents and Publications balance         0.00       0.94      0.00      0.01
# The most citation                       39.00  107485.00   2218.00   5136.27
# The most citation density                0.04       0.66      0.18      0.20
# Sum of top 10 citations                258.00  214306.00   6407.00  12867.27
# Sum of top 10 citations density         21.50   17858.83    533.92   1072.27
# Observation time window (years)          3.00    2021.00     28.00     73.29
# average citation per publication         9.65    2894.08     60.50     97.60
# average citation per year                0.78   14711.58    374.39    721.56
# average publication per year             0.03      32.22      6.29      7.29
# Cluster                                  3.00       3.00      3.00      3.00
#
#                                            STD      Variance
# Citation                              23822.33  5.675036e+08
# h-index                                  18.07  3.266400e+02
# i10-index                                59.64  3.557320e+03
# No. Of Publications                     148.95  2.218659e+04
# No. Of publications without citation     61.93  3.835410e+03
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                          6.59  4.338000e+01
# Patents and Publications balance          0.05  0.000000e+00
# The most citation                      8488.16  7.204880e+07
# The most citation density                 0.09  1.000000e-02
# Sum of top 10 citations               18853.48  3.554537e+08
# Sum of top 10 citations density        1571.12  2.468428e+06
# Observation time window (years)         283.26  8.023719e+04
# average citation per publication        142.66  2.035046e+04
# average citation per year              1133.02  1.283724e+06
# average publication per year              4.60  2.118000e+01
# Cluster                                   0.00  0.000000e+00
# Cluster 5
#                                       Minimum    Maximum    Median      Mean  \
# Citation                              2247.00  744199.00  30466.00  45494.90
# h-index                                 24.00     299.00     84.00     90.66
# i10-index                               53.00    1904.00    282.00    332.40
# No. Of Publications                     63.00    3000.00    510.00    657.52
# No. Of publications without citation     0.00    1807.00    115.00    178.19
# Uncited rate                             0.00       0.72      0.22      0.22
# No.Of US pattent                         0.00     716.00      0.00      7.45
# Patents and Publications balance         0.00       0.52      0.00      0.01
# The most citation                      106.00  126878.00   1880.00   4250.81
# The most citation density                0.01       0.35      0.06      0.08
# Sum of top 10 citations                737.00  632866.00   8436.00  15361.14
# Sum of top 10 citations density         61.42   52738.83    703.00   1280.10
# Observation time window (years)          6.00    2021.00     37.00     66.40
# average citation per publication         9.16     859.96     58.69     76.75
# average citation per year               12.97   12706.83    779.07   1181.51
# average publication per year             0.22     175.00     13.51     16.80
# Cluster                                  4.00       4.00      4.00      4.00
#
#                                            STD      Variance
# Citation                              47768.89  2.281867e+09
# h-index                                  35.04  1.227680e+03
# i10-index                               220.22  4.849842e+04
# No. Of Publications                     509.33  2.594138e+05
# No. Of publications without citation    203.60  4.145158e+04
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                         27.70  7.673800e+02
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      7586.28  5.755165e+07
# The most citation density                 0.05  0.000000e+00
# Sum of top 10 citations               24354.56  5.931444e+08
# Sum of top 10 citations density        2029.55  4.119058e+06
# Observation time window (years)         205.78  4.234608e+04
# average citation per publication         62.92  3.959100e+03
# average citation per year              1281.10  1.641213e+06
# average publication per year             12.96  1.680200e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 6
#                                       Minimum   Maximum  Median     Mean  \
# Citation                                 1.00  62374.00  915.00  2017.73
# h-index                                  1.00     50.00   14.00    15.22
# i10-index                                0.00    144.00   17.00    22.03
# No. Of Publications                      5.00    852.00   53.00    68.62
# No. Of publications without citation     2.00    506.00   17.00    24.55
# Uncited rate                             0.10      0.96    0.33     0.35
# No.Of US pattent                         0.00     23.00    0.00     0.22
# Patents and Publications balance         0.00      0.31    0.00     0.00
# The most citation                        1.00  18288.00  219.50   577.82
# The most citation density                0.08      1.00    0.25     0.28
# Sum of top 10 citations                  1.00  60074.00  700.00  1552.19
# Sum of top 10 citations density          0.08   5006.17   58.33   129.35
# Observation time window (years)          2.00   2021.00   21.00    25.59
# average citation per publication         0.10    390.07   17.15    25.76
# average citation per year                0.10   2835.18   45.86    87.00
# average publication per year             0.10     19.20    2.61     3.09
# Cluster                                  5.00      5.00    5.00     5.00
#
#                                           STD     Variance
# Citation                              3557.66  12656949.32
# h-index                                  8.26        68.27
# i10-index                               18.39       338.22
# No. Of Publications                     59.98      3598.13
# No. Of publications without citation    29.06       844.61
# Uncited rate                             0.13         0.02
# No.Of US pattent                         1.24         1.53
# Patents and Publications balance         0.02         0.00
# The most citation                     1249.83   1562084.12
# The most citation density                0.12         0.02
# Sum of top 10 citations               3045.20   9273245.47
# Sum of top 10 citations density        253.77     64397.54
# Observation time window (years)         47.03      2211.55
# average citation per publication        30.84       951.14
# average citation per year              150.72     22716.91
# average publication per year             2.03         4.11
# Cluster                                  0.00         0.00

# %% [markdown]
# # Find minimum and maximum in all clusters

# %%
max = {}
min = {}
max_cluster = {}
min_cluster = {}
for cluster in min_max_clusters:
  for item in cluster['max']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = max.get(col, 0)
      if value > v:
        max[col] = value
        max_cluster[col] = cluster['cluster'] + 1
  for item in cluster['min']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = min.get(col, 100000000)
      if value < v:
        min[col] = value
        min_cluster[col] = cluster['cluster'] + 1

# %%
from pprint import pprint
print('Max:', end="\n\n")
pprint(max_cluster, indent=2)

print('\n\nMin:', end="\n\n")
pprint(min_cluster, indent=2)
# Out:
# Max:
#
# { 'Citation': 5,
#   'No. Of Publications': 5,
#   'No. Of publications without citation': 5,
#   'No.Of US pattent': 5,
#   'Observation time window (years)': 2,
#   'Patents and Publications balance': 2,
#   'Sum of top 10 citations': 5,
#   'Sum of top 10 citations density': 5,
#   'The most citation': 5,
#   'The most citation density': 3,
#   'Uncited rate': 6,
#   'average citation per publication': 3,
#   'average citation per year': 3,
#   'average publication per year': 5,
#   'h-index': 5,
#   'i10-index': 5}
#
#
# Min:
#
# { 'Citation': 3,
#   'No. Of Publications': 3,
#   'No. Of publications without citation': 3,
#   'No.Of US pattent': 1,
#   'Observation time window (years)': 2,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 3,
#   'Sum of top 10 citations density': 3,
#   'The most citation': 3,
#   'The most citation density': 2,
#   'Uncited rate': 3,
#   'average citation per publication': 6,
#   'average citation per year': 6,
#   'average publication per year': 3,
#   'h-index': 3,
#   'i10-index': 1}

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# # Import dataset

# %%
df = pd.read_excel('../Data-gathering/Json/Final_Dataset.xlsx')
df = df.drop(['Index',
           'Date',
           'index',
           'Author name',
           'University',
           'country',
           'Google Scholar link of the university',
           'Google Scholar link of the author',
           'Qs uni world ranking',
           'Qs uni country ranking',
           'Date of the first publication (year)',
           'Date of the last publication (year)',
            "Author's positin in top 100 pages",
            ], axis=1)
cols = df.columns
main_df = df

# %% [markdown]
# # Minmax scaler

# %%
scaler = preprocessing.MinMaxScaler()
scaled = scaler.fit_transform(main_df)
min_maxed_df = pd.DataFrame(scaled, columns=[cols])

# %% [markdown]
# # Normalization

# %%
df_normalized = preprocessing.normalize(min_maxed_df)
dfcopy = df_normalized
df = pd.DataFrame(df_normalized, columns=[cols])

# %% [markdown]
# # PCA

# %%
pca = PCA(2)
data = pca.fit_transform(df)
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(data)

label = kmeans.fit_predict(data)
fig, ax = plt.subplots(figsize=(10, 10))

u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(data[label == i , 0] , data[label == i , 1] )
plt.show()

# %% [markdown]
# # Trian model with 5 clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df)

label = kmeans.fit_predict(df)
print(label)
# Out:
# [1 1 1 ... 2 0 3]

# %% [markdown]
# # Assign clusters to dataframe

# %%
main_df['Cluster'] = label
main_df = main_df.astype({"Cluster": int})

# %% [markdown]
# # Export dataset with label column

# %%
main_df.to_excel('Labled_Dataset_Without_Author_Rank.xlsx')

# %% [markdown]
# # Clusters histogram

# %%
main_df['Cluster'].hist()
# Out:
# <AxesSubplot:>

# %%
cluster_groups = main_df.groupby('Cluster')

# %% [markdown]
# # Histogram of each cluster

# %%
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
  fig.suptitle(f'Cluster {cluster + 1}', fontsize=16)
  i = 0
  j = 0
  for col in group.columns:
      if j == 4:
          i += 1
          j = 0
      if col == 'Cluster':
        pass
      else:
        ax[i, j].set(title = col)
        ax[i, j].hist(group[col])
      j += 1

# %% [markdown]
# # Data summary of each cluster

# %%
min_max_clusters = []
for cluster, _ in enumerate(cluster_groups):
  group = cluster_groups.get_group(cluster)
  statistical = []
  temp_min_max = {
      'cluster': cluster,
      'min': [],
      'max': [],
  }
  for col in group.columns:
      statistical_par = {
              'Minimum': round(group[col].min(),2),
              'Maximum': round(group[col].max(),2),
              'Median':  round(group[col].median(),2),
              'Mean':    round(group[col].mean(),2),
              'STD':     round(group[col].std(),2),
              'Variance':round(group[col].var(),2)
          }
      
      temp_min_max['max'].append({col:statistical_par['Maximum']})
      temp_min_max['min'].append({col:statistical_par['Minimum']})
      statistical.append(statistical_par)
  min_max_clusters.append(temp_min_max)
  temp = pd.DataFrame(
      statistical, 
      index = group.columns
  )
  print(f"\n\nCluster {cluster + 1}", end="\n")
  display(temp)
# Out:
# Cluster 1
#                                       Minimum   Maximum   Median     Mean  \
# Citation                                14.00  41249.00  1601.00  2414.74
# h-index                                  2.00     56.00    21.00    21.74
# i10-index                                0.00    123.00    35.00    39.16
# No. Of Publications                     10.00    892.00   115.00   138.60
# No. Of publications without citation     5.00    697.00    41.00    57.53
# Uncited rate                             0.13      0.91     0.38     0.39
# No.Of US pattent                         0.00    344.00     0.00     0.42
# Patents and Publications balance         0.00      0.95     0.00     0.00
# The most citation                        3.00   6711.00   176.00   308.16
# The most citation density                0.03      0.44     0.12     0.13
# Sum of top 10 citations                 14.00  35356.00   852.00  1332.44
# Sum of top 10 citations density          1.17   2946.33    71.00   111.04
# Observation time window (years)          3.00   2021.00    26.00    32.74
# average citation per publication         0.19    513.75    13.27    17.65
# average citation per year                0.47   3746.38    59.13    90.98
# average publication per year             0.18     32.82     4.35     5.02
# Cluster                                  0.00      0.00     0.00     0.00
#
#                                           STD    Variance
# Citation                              2910.24  8469504.06
# h-index                                  9.63       92.82
# i10-index                               24.45      598.02
# No. Of Publications                     95.90     9197.50
# No. Of publications without citation    55.76     3109.50
# Uncited rate                             0.12        0.01
# No.Of US pattent                         6.33       40.08
# Patents and Publications balance         0.02        0.00
# The most citation                      477.78   228271.43
# The most citation density                0.05        0.00
# Sum of top 10 citations               1978.06  3912709.29
# Sum of top 10 citations density        164.84    27171.59
# Observation time window (years)         54.97     3021.75
# average citation per publication        20.40      416.25
# average citation per year              151.93    23081.46
# average publication per year             3.06        9.39
# Cluster                                  0.00        0.00
# Cluster 2
#                                       Minimum    Maximum    Median      Mean  \
# Citation                               900.00  744199.00  29893.00  44320.69
# h-index                                 19.00     299.00     81.00     87.26
# i10-index                               27.00    1904.00    260.00    309.66
# No. Of Publications                     30.00    3000.00    467.00    604.07
# No. Of publications without citation     0.00    1424.00    101.00    160.02
# Uncited rate                             0.00       0.66      0.21      0.21
# No.Of US pattent                         0.00     716.00      0.00      6.82
# Patents and Publications balance         0.00       0.94      0.00      0.01
# The most citation                       50.00  126878.00   2015.00   4737.73
# The most citation density                0.01       0.40      0.07      0.09
# Sum of top 10 citations                343.00  632866.00   8711.00  16145.19
# Sum of top 10 citations density         28.58   52738.83    725.92   1345.43
# Observation time window (years)          3.00    2021.00     36.00     74.82
# average citation per publication         9.16     919.08     62.71     84.70
# average citation per year                2.84   13599.33    774.76   1208.46
# average publication per year             0.07     175.00     12.63     15.71
# Cluster                                  1.00       1.00      1.00      1.00
#
#                                            STD      Variance
# Citation                              46775.64  2.187961e+09
# h-index                                  35.31  1.246620e+03
# i10-index                               218.87  4.790559e+04
# No. Of Publications                     498.19  2.481967e+05
# No. Of publications without citation    191.80  3.678755e+04
# Uncited rate                              0.10  1.000000e-02
# No.Of US pattent                         26.33  6.934800e+02
# Patents and Publications balance          0.04  0.000000e+00
# The most citation                      8210.30  6.740907e+07
# The most citation density                 0.06  0.000000e+00
# Sum of top 10 citations               24642.08  6.072320e+08
# Sum of top 10 citations density        2053.51  4.216889e+06
# Observation time window (years)         248.00  6.150446e+04
# average citation per publication         75.36  5.679280e+03
# average citation per year              1356.37  1.839740e+06
# average publication per year             12.57  1.580100e+02
# Cluster                                   0.00  0.000000e+00
# Cluster 3
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  176539.00  2071.00  7416.36
# h-index                                  1.00      87.00    16.00    20.07
# i10-index                                0.00     263.00    19.00    33.56
# No. Of Publications                      1.00     511.00    41.00    67.77
# No. Of publications without citation     0.00     218.00     6.00    14.88
# Uncited rate                             0.00       0.67     0.18     0.20
# No.Of US pattent                         0.00      47.00     0.00     0.43
# Patents and Publications balance         0.00       0.83     0.00     0.00
# The most citation                        1.00  126317.00   750.00  3731.03
# The most citation density                0.09       1.00     0.42     0.46
# Sum of top 10 citations                  1.00  188615.00  1746.00  6369.11
# Sum of top 10 citations density          0.08   15717.92   145.50   530.76
# Observation time window (years)          1.00    2013.00    17.00    26.32
# average citation per publication         0.50    4864.50    48.76   106.67
# average citation per year                0.42   16344.62   127.09   354.81
# average publication per year             0.01      27.55     2.42     3.22
# Cluster                                  2.00       2.00     2.00     2.00
#
#                                            STD      Variance
# Citation                              14169.24  2.007674e+08
# h-index                                  15.34  2.353300e+02
# i10-index                                38.00  1.444270e+03
# No. Of Publications                      75.98  5.773040e+03
# No. Of publications without citation     23.51  5.526600e+02
# Uncited rate                              0.13  2.000000e-02
# No.Of US pattent                          2.37  5.640000e+00
# Patents and Publications balance          0.03  0.000000e+00
# The most citation                      8705.70  7.578916e+07
# The most citation density                 0.22  5.000000e-02
# Sum of top 10 citations               14274.75  2.037686e+08
# Sum of top 10 citations density        1189.56  1.415060e+06
# Observation time window (years)         107.14  1.147846e+04
# average citation per publication        248.49  6.174684e+04
# average citation per year               821.76  6.752885e+05
# average publication per year              2.68  7.180000e+00
# Cluster                                   0.00  0.000000e+00
# Cluster 4
#                                       Minimum    Maximum   Median     Mean  \
# Citation                                 1.00  104130.00  1415.00  4175.48
# h-index                                  1.00      87.00    17.00    19.87
# i10-index                                0.00     247.00    23.00    33.79
# No. Of Publications                      4.00     903.00    62.00    90.18
# No. Of publications without citation     2.00     506.00    18.00    29.28
# Uncited rate                             0.06       0.96     0.30     0.32
# No.Of US pattent                         0.00      45.00     0.00     0.39
# Patents and Publications balance         0.00       0.53     0.00     0.00
# The most citation                        1.00   42314.00   314.00  1219.64
# The most citation density                0.08       1.00     0.25     0.28
# Sum of top 10 citations                  1.00   91469.00  1014.00  3059.25
# Sum of top 10 citations density          0.08    7622.42    84.50   254.94
# Observation time window (years)          2.00    2021.00    22.00    30.78
# average citation per publication         0.10     732.71    22.15    36.40
# average citation per year                0.10    4120.17    65.57   156.28
# average publication per year             0.03      26.15     2.96     3.67
# Cluster                                  3.00       3.00     3.00     3.00
#
#                                           STD     Variance
# Citation                              8280.37  68564531.73
# h-index                                 13.05       170.18
# i10-index                               33.24      1104.97
# No. Of Publications                     87.68      7687.44
# No. Of publications without citation    37.42      1400.03
# Uncited rate                             0.13         0.02
# No.Of US pattent                         2.07         4.27
# Patents and Publications balance         0.02         0.00
# The most citation                     2905.41   8441393.38
# The most citation density                0.13         0.02
# Sum of top 10 citations               6755.36  45634949.11
# Sum of top 10 citations density        562.95    316909.37
# Observation time window (years)         99.54      9908.93
# average citation per publication        50.34      2534.54
# average citation per year              285.73     81641.79
# average publication per year             2.68         7.18
# Cluster                                  0.00         0.00
# Cluster 5
#                                       Minimum    Maximum   Median      Mean  \
# Citation                               568.00  225629.00  9667.50  12839.87
# h-index                                 10.00     150.00    49.00     51.34
# i10-index                               12.00     503.00   130.00    144.07
# No. Of Publications                     43.00    2527.00   315.00    381.22
# No. Of publications without citation     5.00    1807.00    94.00    138.47
# Uncited rate                             0.07       0.94     0.29      0.31
# No.Of US pattent                         0.00     120.00     0.00      2.08
# Patents and Publications balance         0.00       0.27     0.00      0.01
# The most citation                       22.00   44738.00   677.00   1342.71
# The most citation density                0.01       0.43     0.08      0.09
# Sum of top 10 citations                186.00  214306.00  3221.00   5142.92
# Sum of top 10 citations density         15.50   17858.83   268.42    428.58
# Observation time window (years)          1.00    2021.00    34.00     47.12
# average citation per publication         1.24    1683.80    30.04     38.47
# average citation per year                1.29    6267.47   273.22    369.62
# average publication per year             0.09     145.86     9.10     10.78
# Cluster                                  4.00       4.00     4.00      4.00
#
#                                            STD      Variance
# Citation                              11594.15  1.344242e+08
# h-index                                  16.57  2.746500e+02
# i10-index                                65.87  4.339300e+03
# No. Of Publications                     261.28  6.826470e+04
# No. Of publications without citation    152.23  2.317280e+04
# Uncited rate                              0.11  1.000000e-02
# No.Of US pattent                          7.29  5.308000e+01
# Patents and Publications balance          0.02  0.000000e+00
# The most citation                      2250.07  5.062803e+06
# The most citation density                 0.05  0.000000e+00
# Sum of top 10 citations                7136.28  5.092648e+07
# Sum of top 10 citations density         594.69  3.536561e+05
# Observation time window (years)         118.40  1.401836e+04
# average citation per publication         42.67  1.820930e+03
# average citation per year               367.18  1.348214e+05
# average publication per year              7.50  5.632000e+01
# Cluster                                   0.00  0.000000e+00

# %% [markdown]
# # Find minimum and maximum in all clusters

# %%
max = {}
min = {}
max_cluster = {}
min_cluster = {}
for cluster in min_max_clusters:
  for item in cluster['max']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = max.get(col, 0)
      if value > v:
        max[col] = value
        max_cluster[col] = cluster['cluster'] + 1
  for item in cluster['min']:
    col, value = list(item.items())[0]
    if col != "Cluster":
      v = min.get(col, 100000000)
      if value < v:
        min[col] = value
        min_cluster[col] = cluster['cluster'] + 1

# %%
from pprint import pprint

# Most of maximums are in cluster 2
print('Max:', end="\n\n")
pprint(max_cluster, indent=2)

# Most of minimums are in cluster 3
print('\n\nMin:', end="\n\n")
pprint(min_cluster, indent=2)
# Out:
# Max:
#
# { 'Citation': 2,
#   'No. Of Publications': 2,
#   'No. Of publications without citation': 5,
#   'No.Of US pattent': 2,
#   'Observation time window (years)': 1,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 2,
#   'Sum of top 10 citations density': 2,
#   'The most citation': 2,
#   'The most citation density': 3,
#   'Uncited rate': 4,
#   'average citation per publication': 3,
#   'average citation per year': 3,
#   'average publication per year': 2,
#   'h-index': 2,
#   'i10-index': 2}
#
#
# Min:
#
# { 'Citation': 3,
#   'No. Of Publications': 3,
#   'No. Of publications without citation': 2,
#   'No.Of US pattent': 1,
#   'Observation time window (years)': 3,
#   'Patents and Publications balance': 1,
#   'Sum of top 10 citations': 3,
#   'Sum of top 10 citations density': 3,
#   'The most citation': 3,
#   'The most citation density': 2,
#   'Uncited rate': 2,
#   'average citation per publication': 4,
#   'average citation per year': 4,
#   'average publication per year': 3,
#   'h-index': 3,
#   'i10-index': 1}

# %% [markdown]
# # Implement codebook

# %%
clusterCenters = kmeans.cluster_centers_
kmeansInertias.append(kmeans.inertia_)
centroidsTable = pd.DataFrame(clusterCenters, columns=df.columns[:17], index = ['C'+str(i+1) for i in range(len(clusterCenters))])

display(centroidsTable)
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.007632  0.170598  0.050363            0.104394
# C2  0.098218  0.584051  0.296242            0.345738
# C3  0.018919  0.160440  0.042693            0.049877
# C4  0.012683  0.167299  0.046223            0.071761
# C5  0.037705  0.409427  0.176806            0.274440
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.066771     0.914836         0.001182
# C2                             0.132848     0.436704         0.014904
# C3                             0.014726     0.392355         0.001126
# C4                             0.034423     0.744572         0.001335
# C5                             0.148229     0.755264         0.006065
#
#    Patents and Publications balance The most citation  \
# C1                         0.006571          0.005482
# C2                         0.022004          0.059048
# C3                         0.009107          0.045858
# C4                         0.010710          0.019452
# C5                         0.013739          0.021988
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.280842                0.004909
# C2                  0.186556                0.042741
# C3                  0.849577                0.018008
# C4                  0.595590                0.010617
# C5                  0.198021                0.017684
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.004909                        0.035952
# C2                        0.042741                        0.057435
# C3                        0.018008                        0.024843
# C4                        0.010617                        0.032768
# C5                        0.017684                        0.050098
#
#    average citation per publication average citation per year  \
# C1                         0.009065                  0.013416
# C2                         0.038490                  0.133545
# C3                         0.042506                  0.042377
# C4                         0.018910                  0.023344
# C5                         0.019971                  0.051678
#
#    average publication per year
# C1                     0.067908
# C2                     0.172561
# C3                     0.045117
# C4                     0.054041
# C5                     0.142282

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
i = 0
j = 0
display(centroidsTable)
for col in centroidsTable.columns:
    if j == 4:
        i += 1
        j = 0
    ax[i, j].set(title = col)
    ax[i, j].plot(centroidsTable[col], linestyle = 'dotted')
    j += 1
# Out:
#     Citation   h-index i10-index No. Of Publications  \
# C1  0.007632  0.170598  0.050363            0.104394
# C2  0.098218  0.584051  0.296242            0.345738
# C3  0.018919  0.160440  0.042693            0.049877
# C4  0.012683  0.167299  0.046223            0.071761
# C5  0.037705  0.409427  0.176806            0.274440
#
#    No. Of publications without citation Uncited rate No.Of US pattent  \
# C1                             0.066771     0.914836         0.001182
# C2                             0.132848     0.436704         0.014904
# C3                             0.014726     0.392355         0.001126
# C4                             0.034423     0.744572         0.001335
# C5                             0.148229     0.755264         0.006065
#
#    Patents and Publications balance The most citation  \
# C1                         0.006571          0.005482
# C2                         0.022004          0.059048
# C3                         0.009107          0.045858
# C4                         0.010710          0.019452
# C5                         0.013739          0.021988
#
#    The most citation density Sum of top 10 citations  \
# C1                  0.280842                0.004909
# C2                  0.186556                0.042741
# C3                  0.849577                0.018008
# C4                  0.595590                0.010617
# C5                  0.198021                0.017684
#
#    Sum of top 10 citations density Observation time window (years)  \
# C1                        0.004909                        0.035952
# C2                        0.042741                        0.057435
# C3                        0.018008                        0.024843
# C4                        0.010617                        0.032768
# C5                        0.017684                        0.050098
#
#    average citation per publication average citation per year  \
# C1                         0.009065                  0.013416
# C2                         0.038490                  0.133545
# C3                         0.042506                  0.042377
# C4                         0.018910                  0.023344
# C5                         0.019971                  0.051678
#
#    average publication per year
# C1                     0.067908
# C2                     0.172561
# C3                     0.045117
# C4                     0.054041
# C5                     0.142282
